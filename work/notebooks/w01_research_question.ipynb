# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose lane2:Refresh/content opportunity scoring because it combine data analyis and mahine learning to solve a  real word business problem .The goal is to identify which content page should be reviewes first and update search and engagement signals .The allow baseline scorng system ,improve it using mahine learning and generate a ranked lit of recommendation which will help to reviewer priortize the work

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Descision: Prioritize pages for content refresh and review
# action: Content managers,SEO specialists or reviewer are reponsible for imporving the website content
#
# Wrong Call:
# If a low -priority page is recommended ,reviewer may waste there time and but the most important they will loss the traffic on their site

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import pandas as pd

# Check candidate paths for robustness
paths = [
    "data/raw/content_refresh_anonymized.csv",
    "../data/raw/content_refresh_anonymized.csv",
    r"E:\flyrank-ml-internship-starter-main\flyrank-ml-internship-starter-main\data\raw\content_refresh_anonymized.csv"
]

df = None
for path in paths:
    if os.path.exists(path):
        df = pd.read_csv(path)
        print(f"Loaded CSV from: {path}")
        break

if df is None:
    try:
        df  # use existing df from earlier cell if available
        print("Using existing DataFrame 'df' from earlier cell")
    except NameError:
        raise FileNotFoundError("CSV not found at any candidate paths and 'df' is not defined.")

# Quick checks / 2-3 real numbers to justify lane
print("\nShape:", df.shape)
print("\nTop 3 rows:")
print(df.head(3).to_string(index=False))

num_cols = df.select_dtypes(include='number').columns.tolist()
if num_cols:
    print("\nNumeric summary (min, median, mean, max) for numeric columns:")
    print(df[num_cols].agg(['min', 'median', 'mean', 'max']).transpose())
else:
    print("\nNo numeric columns found.")

print("\nMissing values per column:")
print(df.isna().sum())
# Out:
# Loaded CSV from: E:\flyrank-ml-internship-starter-main\flyrank-ml-internship-starter-main\data\raw\content_refresh_anonymized.csv
#
# Shape: (30000, 44)
#
# Top 3 rows:
#           content_id         client_id  search_volume  competition competition_level  cpc    content_type   main_intent  word_count  char_count provider_used             model_used  impressions_90d  clicks_90d  pageviews_90d  sessions_90d  users_90d  engaged_sessions_90d  ai_sessions_90d  scroll_events_90d  days_with_impressions  days_with_sessions  impressions_last_30d  clicks_last_30d  sessions_last_30d  impressions_prev_30d  clicks_prev_30d  sessions_prev_30d  content_age_days age_tier  age_tier_order  days_since_last_update freshness_tier word_count_tier char_count_tier  ctr  avg_position  engagement_rate  scroll_rate  ai_traffic_pct impression_tier position_tier trend_direction  trend_pct
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project will analyze obervable search and engagement signals to idenfy page that appear to be good candidates for review. The recommandation will e based on mearured patterns in the data will provide decision support for content reviewer. The result may show directional relationshipe btw features such as impressions ,CTR , content age, and declining performance
#
# This project cannot prove that refressing a page will increase traffic, identfy Google's ranking algorthm or establish cause and effec relationshipe.The model provides evidence-based recommandations rather than guraranteed outcomes nd human review is still requred before any content  changes are made

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
