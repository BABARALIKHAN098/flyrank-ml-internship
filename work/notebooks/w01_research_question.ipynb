# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose **Lane 2: Refresh / Content Opportunity Scoring** because it combines data analysis and machine learning to solve a real business problem. The goal is to identify which content pages should be reviewed first based on search and engagement signals. This lane allows me to build a baseline scoring system, improve it using machine learning, and generate a ranked list of recommendations that can help content reviewers prioritize their work efficiently.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# Which content pages should be reviewed first because they are most likely to lose search performance or have strong opportunities for improvement?
#
# **Decision:**
# Prioritize pages for content refresh and review.
#
# **Who acts on it?**
# Content managers, SEO specialists, and reviewers responsible for improving website content.
#
# **Cost of a wrong recommendation:**
# If a low-priority page is recommended, reviewers may spend time updating content that has little impact. If an important page is missed, the business may lose search visibility, clicks, and potential visitors. The model is intended to support human decision-making rather than replace it.

# %% [markdown]
# ## 3. Quick look at the data (2–3 real numbers)
#
# *Load the starter CSV below and show 2–3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

print('Number of rows:', len(df))
print('Number of columns:', len(df.columns))
print('Pages with impressions > 0:', (df['impressions_90d'] > 0).sum())

print('\nAverage impressions:', round(df['impressions_90d'].mean(), 2))
print('Average CTR:', round(df['ctr'].mean(), 2))
print('Average sessions:', round(df['sessions_90d'].mean(), 2))

# %% [markdown]
# ### Observation
#
# The starter dataset contains multiple search performance metrics, including impressions, clicks, CTR, sessions, content age, and trend information. These observable signals provide enough information to analyze page performance and build a content opportunity scoring model. Replace this paragraph with the actual numbers printed by the code after running the notebook.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project analyzes observable search and engagement signals to identify pages that appear to be good candidates for review. The recommendations are based on measured patterns in the data and provide decision support for content reviewers. The results may show directional relationships between features such as impressions, CTR, content age, and declining performance.
#
# This project cannot prove that refreshing a page will increase traffic, predict Google's ranking algorithm, or establish cause-and-effect relationships. The model provides evidence-based recommendations rather than guaranteed outcomes, and human review is still required before any content changes are made.

# %% [markdown]
# ## Self-check
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it.
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all).
# - [x] No client names, URLs, or private queries anywhere.
# - [x] My claims use careful words: observed, measured, directional, decision-support.
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card.
